# %%
import pandas as pd

# %%
weatherDisasterCSV = "Resources/disaster_data.csv"
wDisaster_df = pd.read_csv(weatherDisasterCSV)
wDisaster_df = wDisaster_df.loc[wDisaster_df["ISO"] == "USA", :]
wDisaster_df
# Out:
#             Dis No  Year   Seq Disaster Group Disaster Subgroup Disaster Type  \
# 2    2000-0080-USA  2000    80        Natural      Hydrological         Flood
# 3    2000-0500-USA  2000   500        Natural      Hydrological         Flood
# 4    2000-0919-USA  2000   919        Natural    Meteorological         Storm
# 5    2000-9712-USA  2000  9712        Natural    Climatological       Drought
# 6    2000-0838-USA  2000   838        Natural    Meteorological         Storm
# ..             ...   ...   ...            ...               ...           ...
# 532  2019-0307-USA  2019   307        Natural      Hydrological         Flood
# 533  2020-0148-USA  2020   148        Natural    Meteorological         Storm
# 534  2020-0011-USA  2020    11        Natural    Meteorological         Storm
# 535  2020-0082-USA  2020    82        Natural    Meteorological         Storm
# 536  2020-0219-USA  2020   219        Natural    Meteorological         Storm
#
# ...

# %%
wDisaster_df["Location"].value_counts()
# Out:
# Texas province                                                                                                                                                                                                                                                                                                                                                                                                       4
# Arizona province                                                                                                                                                                                                                                                                                                                                                                                                     3
# ...

# %%
newData = {
    "Location": [],
    "Total Damages ('000 US$)": []
}

for index, row in wDisaster_df.iterrows():
    #print(type(newData["Location"]))
    if type(row["Location"]) is str:
        for location in row["Location"].split(","):
            newData["Location"].append(location)
            newData["Total Damages ('000 US$)"].append(row["Total Damages ('000 US$)"])
pd.DataFrame(newData)
# Out:
#                                      Location  Total Damages ('000 US$)
# 0                                    Kentucky                       NaN
# 1                              Ohio provinces                       NaN
# 2                                      Morris                  166000.0
# 3      Sussex districts (New Jersey province)                  166000.0
# 4                                     Alabama                  350000.0
# ...                                       ...                       ...
# 4019                                  Georgia                 1100000.0
# 4020                                    Texas                 1100000.0
# 4021                                errebonne                  325000.0
# 4022                              Plaquemines                  325000.0
# 4023           Lafourche Parishes (Louisiana)                  325000.0
#
# [4024 rows x 2 columns]

# %%
print(wDisaster_df.columns)
wDisaster_df.groupby("Disaster Type").count()
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Entry Criteria', 'Country', 'ISO', 'Region', 'Continent',
#        'Location', 'Origin', 'Associated Dis', 'Associated Dis2',
#        'OFDA Response', 'Appeal', 'Declaration', 'Aid Contribution',
#        'Dis Mag Value', 'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time',
#        'River Basin', 'Start Year', 'Start Month', 'Start Day', 'End Year',
#        'End Month', 'End Day', 'Total Deaths', 'No Injured', 'No Affected',
#        'No Homeless', 'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Insured Damages ('000 US$)', 'Total Damages ('000 US$)', 'CPI'],
#       dtype='object')
#                      Dis No  Year  Seq  Disaster Group  Disaster Subgroup  \
# Disaster Type
# Drought                  11    11   11              11                 11
# ...

# %%
disasterNo_df = wDisaster_df.loc[:, ["Dis No", "Location"]]
disasterNo
# Out:
#             Dis No                                           Location
# 2    2000-0080-USA                           Kentucky, Ohio provinces
# 3    2000-0500-USA     Morris, Sussex districts (New Jersey province)
# 4    2000-0919-USA  Alabama, Georgia, Louisiana, North Carolina, S...
# 5    2000-9712-USA                                   Wyoming province
# 6    2000-0838-USA  Texas, Oklahoma, New Mexico, Arkansas, Missour...
# ..             ...                                                ...
# 532  2019-0307-USA  Lincolnton region (Lincoln County, North Carol...
# 533  2020-0148-USA  Louisiana, Texas, Mississippi, South Carolina,...
# 534  2020-0011-USA  Texas, Oklahoma, Missouri, Arkansas, Louisiana...
# 535  2020-0082-USA  Nashville (Tennessee), Kentucky, Missouri, Mis...
# 536  2020-0219-USA  errebonne, Plaquemines, Lafourche Parishes (Lo...
#
# [474 rows x 2 columns]

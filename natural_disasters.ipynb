# %%
import pandas as pd
import requests
import json
from pprint import pprint
from config import openWeatherKey

# %%
weatherDisasterCSV = "Resources/disaster_data.csv"
wDisaster_df = pd.read_csv(weatherDisasterCSV)
desiredColumns = ["Dis No", "Year", "Seq", "Disaster Subgroup", "Disaster Type", "Disaster Subtype", "Disaster Subsubtype", "Entry Criteria", "ISO", "Location", "Start Month", "End Month", "Total Deaths", "No Injured", "No Affected", "No Homeless", "Total Affected", "Insured Damages ('000 US$)", "Total Damages ('000 US$)", "CPI"]
wDisaster_df = wDisaster_df.loc[wDisaster_df["ISO"] == "USA", desiredColumns]
wDisaster_df
# Out:
#             Dis No  Year   Seq Disaster Subgroup Disaster Type  \
# 2    2000-0080-USA  2000    80      Hydrological         Flood
# 3    2000-0500-USA  2000   500      Hydrological         Flood
# 4    2000-0919-USA  2000   919    Meteorological         Storm
# 5    2000-9712-USA  2000  9712    Climatological       Drought
# 6    2000-0838-USA  2000   838    Meteorological         Storm
# ..             ...   ...   ...               ...           ...
# 532  2019-0307-USA  2019   307      Hydrological         Flood
# 533  2020-0148-USA  2020   148    Meteorological         Storm
# 534  2020-0011-USA  2020    11    Meteorological         Storm
# 535  2020-0082-USA  2020    82    Meteorological         Storm
# 536  2020-0219-USA  2020   219    Meteorological         Storm
#
#      Disaster Subtype    Disaster Subsubtype Entry Criteria  ISO  \
# 2      Riverine flood                    NaN         Affect  USA
# 3      Riverine flood                    NaN         Affect  USA
# 4                 NaN                    NaN         SigDam  USA
# 5             Drought                    NaN       Affected  USA
# 6    Convective storm  Winter storm/Blizzard           Kill  USA
# ..                ...                    ...            ...  ...
# 532               NaN                    NaN       Affected  USA
# 533  Convective storm                Tornado           Kill  USA
# 534  Convective storm           Severe storm           Kill  USA
# 535  Convective storm                Tornado        Waiting  USA
# 536  Tropical cyclone                    NaN       Affected  USA
#
#                                               Location  Start Month  \
# 2                             Kentucky, Ohio provinces            2
# 3       Morris, Sussex districts (New Jersey province)            8
# 4    Alabama, Georgia, Louisiana, North Carolina, S...            1
# 5                                     Wyoming province           11
# 6    Texas, Oklahoma, New Mexico, Arkansas, Missour...           12
# ..                                                 ...          ...
# 532  Lincolnton region (Lincoln County, North Carol...            6
# 533  Louisiana, Texas, Mississippi, South Carolina,...            4
# 534  Texas, Oklahoma, Missouri, Arkansas, Louisiana...            1
# 535  Nashville (Tennessee), Kentucky, Missouri, Mis...            3
# 536  errebonne, Plaquemines, Lafourche Parishes (Lo...            6
#
#      End Month  Total Deaths  No Injured  No Affected  No Homeless  \
# 2          2.0           3.0         NaN        231.0          NaN
# 3          8.0           NaN         NaN        175.0          NaN
# 4          1.0           4.0         NaN          NaN          NaN
# 5          NaN           NaN         NaN          NaN          NaN
# 6         12.0          57.0        34.0          NaN          NaN
# ..         ...           ...         ...          ...          ...
# 532        6.0           3.0         NaN        600.0          NaN
# 533        4.0          38.0       200.0          NaN          NaN
# 534        1.0          12.0         NaN          NaN          NaN
# 535        3.0          25.0       300.0      12000.0          NaN
# 536        6.0           1.0         NaN          NaN          NaN
#
#      Total Affected  Insured Damages ('000 US$)  Total Damages ('000 US$)  \
# 2             231.0                         NaN                       NaN
# 3             175.0                         NaN                  166000.0
# 4               NaN                    280000.0                  350000.0
# 5               NaN                         NaN                       NaN
# 6              34.0                    200500.0                   10000.0
# ..              ...                         ...                       ...
# 532           600.0                         NaN                       NaN
# 533           200.0                         NaN                 1000000.0
# 534             NaN                         NaN                 1200000.0
# 535         12300.0                         NaN                 1100000.0
# 536             NaN                         NaN                  325000.0
#
#             CPI
# 2     67.355759
# 3     67.355759
# 4     67.355759
# 5     67.355759
# 6     67.355759
# ..          ...
# 532  100.000000
# 533         NaN
# 534         NaN
# 535         NaN
# 536         NaN
#
# [474 rows x 20 columns]

# %%
wDisaster_df["Location"].value_counts()
# Out:
# Texas province                                                                                                                     4
# Illinois, Indiana, Iowa, Kansas, Michigan, Minnesota, Missouri, Nebraska, North Dakota, Ohio, South Dakota, Wisconsin provinces    3
# Arizona province                                                                                                                   3
# California province                                                                                                                3
# Los Angeles district (California province)                                                                                         3
#                                                                                                                                   ..
# Wyoming province                                                                                                                   1
# Arkansas, Illinois, Indiana, Kentucky, Missouri, New York, Ohio, Tennessee, Alabama, Mississippi provinces                         1
# Kansas, Nebraska, Texas, Oklahoma, Minnesota, Iowa, Wisconsin provinces                                                            1
# California, Nevada, Oregon provinces                                                                                               1
# Mason, Tazewell, Logan, Will, De Witt districts (Illinois province)                                                                1
# Name: Location, Length: 452, dtype: int64

# %%
newData = {
    "Location": [],
    "Dis No": []
}

for index, row in wDisaster_df.iterrows():
    #print(type(newData["Location"]))
    if type(row["Location"]) is str:
        for location in row["Location"].split(","):
            newData["Location"].append(location)
            newData["Dis No"].append(row["Dis No"])
splitLocations_df = pd.DataFrame(newData)
splitLocations_df
# Out:
#                                      Location         Dis No
# 0                                    Kentucky  2000-0080-USA
# 1                              Ohio provinces  2000-0080-USA
# 2                                      Morris  2000-0500-USA
# 3      Sussex districts (New Jersey province)  2000-0500-USA
# 4                                     Alabama  2000-0919-USA
# ...                                       ...            ...
# 4019                                  Georgia  2020-0082-USA
# 4020                                    Texas  2020-0082-USA
# 4021                                errebonne  2020-0219-USA
# 4022                              Plaquemines  2020-0219-USA
# 4023           Lafourche Parishes (Louisiana)  2020-0219-USA
#
# [4024 rows x 2 columns]

# %%
print(wDisaster_df.columns)
wDisaster_df.groupby("Disaster Type").count()
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Disaster Subgroup', 'Disaster Type',
#        'Disaster Subtype', 'Disaster Subsubtype', 'Entry Criteria', 'ISO',
#        'Location', 'Start Month', 'End Month', 'Total Deaths', 'No Injured',
#        'No Affected', 'No Homeless', 'Total Affected',
#        'Insured Damages ('000 US$)', 'Total Damages ('000 US$)', 'CPI'],
#       dtype='object')
#                      Dis No  Year  Seq  Disaster Subgroup  Disaster Subtype  \
# Disaster Type
# Drought                  11    11   11                 11                11
# Earthquake                9     9    9                  9                 9
# Epidemic                  3     3    3                  3                 2
# Extreme temperature      13    13   13                 13                13
# Flood                    94    94   94                 94                79
# Landslide                 3     3    3                  3                 3
# Storm                   278   278  278                278               258
# Volcanic activity         1     1    1                  1                 1
# Wildfire                 62    62   62                 62                52
#
#                      Disaster Subsubtype  Entry Criteria  ISO  Location  \
# Disaster Type
# Drought                                0              11   11        11
# Earthquake                             0               9    9         9
# Epidemic                               0               3    3         2
# Extreme temperature                    2              13   13        13
# Flood                                  0              93   94        94
# Landslide                              0               3    3         3
# Storm                                203             278  278       278
# Volcanic activity                      0               1    1         1
# Wildfire                               0              62   62        62
#
#                      Start Month  End Month  Total Deaths  No Injured  \
# Disaster Type
# Drought                       11          8             0           0
# Earthquake                     9          9             3           7
# Epidemic                       3          3             1           0
# Extreme temperature           13         13            12           1
# Flood                         94         94            70           7
# Landslide                      3          3             3           2
# Storm                        278        278           238         102
# Volcanic activity              1          1             0           0
# Wildfire                      62         62            32          22
#
#                      No Affected  No Homeless  Total Affected  \
# Disaster Type
# Drought                        0            0               0
# Earthquake                     7            2               9
# Epidemic                       3            0               3
# Extreme temperature            0            0               1
# Flood                         69            5              73
# Landslide                      1            1               3
# Storm                         86           29             155
# Volcanic activity              1            0               1
# Wildfire                      26           40              54
#
#                      Insured Damages ('000 US$)  Total Damages ('000 US$)  CPI
# Disaster Type
# Drought                                       3                         9   11
# Earthquake                                    4                         8    9
# Epidemic                                      0                         0    3
# Extreme temperature                           3                         3   13
# Flood                                        22                        54   94
# Landslide                                     0                         2    3
# Storm                                       175                       224  274
# Volcanic activity                             0                         1    1
# Wildfire                                     17                        42   62

# %%
splitLocations_df["Lat"] = ""
splitLocations_df["Long"] = ""
locations = splitLocations_df["Location"]
splitLocations_df
# Out:
#                                      Location         Dis No Lat Long
# 0                                    Kentucky  2000-0080-USA
# 1                              Ohio provinces  2000-0080-USA
# 2                                      Morris  2000-0500-USA
# 3      Sussex districts (New Jersey province)  2000-0500-USA
# 4                                     Alabama  2000-0919-USA
# ...                                       ...            ...  ..  ...
# 4019                                  Georgia  2020-0082-USA
# 4020                                    Texas  2020-0082-USA
# 4021                                errebonne  2020-0219-USA
# 4022                              Plaquemines  2020-0219-USA
# 4023           Lafourche Parishes (Louisiana)  2020-0219-USA
#
# [4024 rows x 4 columns]

# %%
params = {
    "appid": openWeatherKey,
    "units": "imperial"
}
weatherUrl = "http://api.openweathermap.org/data/2.5/weather?"
for index,row in splitLocations_df.iterrows():
    city = row["Location"]
    params["q"] = city
    print(f"Processing Record {index} | {city}")
    loopResponse = requests.get(weatherUrl, params=params).json()
    
    try:
        splitLocations_df.loc[index, "Lat"] = loopResponse['coord']['lat']
        splitLocations_df.loc[index, "Long"] = loopResponse['coord']['lon']

    except KeyError:
        print(f"{index} | {city} has missing data.")
        splitLocations_df.loc[index, "Lat"] = "N/A"
        splitLocations_df.loc[index, "Long"] = "N/A"
# Out:
# Processing Record 0 | Kentucky
# Processing Record 1 |  Ohio provinces
# 1 |  Ohio provinces has missing data.
# Processing Record 2 | Morris
# Processing Record 3 |  Sussex districts (New Jersey province)
# 3 |  Sussex districts (New Jersey province) has missing data.
# Processing Record 4 | Alabama
# Processing Record 5 |  Georgia
# Processing Record 6 |  Louisiana
# Processing Record 7 |  North Carolina
# Processing Record 8 |  South Carolina
# Processing Record 9 |  Tennessee
# Processing Record 10 |  Virginia
# Processing Record 11 |  New York
# Processing Record 12 |  Pennsylvania
# Processing Record 13 |  Massachussetts provinces
# 13 |  Massachussetts provinces has missing data.
# Processing Record 14 | Wyoming province
# 14 | Wyoming province has missing data.
# Processing Record 15 | Texas
# Processing Record 16 |  Oklahoma
# Processing Record 17 |  New Mexico
# Processing Record 18 |  Arkansas
# Processing Record 19 |  Missouri
# Processing Record 20 |  Minnesota provinces
# 20 |  Minnesota provinces has missing data.
# Processing Record 21 | Crittenden
# Processing Record 22 |  Daviess
# 22 |  Daviess has missing data.
# Processing Record 23 |  Webster districts (Kentucky province)
# 23 |  Webster districts (Kentucky province) has missing data.
# Processing Record 24 | Bullock
# Processing Record 25 |  Montgomery districts (Alabama province)
# 25 |  Montgomery districts (Alabama province) has missing data.
# Processing Record 26 |  Colquitt
# Processing Record 27 |  Grady
# 27 |  Grady has missing data.
# Processing Record 28 |  Mitchell
# Processing Record 29 |  Thomas
# Processing Record 30 |  Tift districts (Georgia province)
# 30 |  Tift districts (Georgia province) has missing data.
# Processing Record 31 |  Washington district (Floride province)
# 31 |  Washington district (Floride province) has missing data.
# Processing Record 32 |  Lonoke
# Processing Record 33 |  Prairie
# 33 |  Prairie has missing data.
# Processing Record 34 |  Saline districts (Arkansas province)
# 34 |  Saline districts (Arkansas province) has missing data.
# Processing Record 35 | Fort Worth Texas city (Tarrant district
# 35 | Fort Worth Texas city (Tarrant district has missing data.
# Processing Record 36 |  Texas province)
# 36 |  Texas province) has missing data.
# Processing Record 37 |  Reagan
# 37 |  Reagan has missing data.
# Processing Record 38 |  Burleson districts (Texas province)
# 38 |  Burleson districts (Texas province) has missing data.
# Processing Record 39 | Adams
# Processing Record 40 |  Columbia
# Processing Record 41 |  Crawford
# Processing Record 42 |  Dane
# Processing Record 43 |  Dodge
# 43 |  Dodge has missing data.
# Processing Record 44 |  Grant
# Processing Record 45 |  Green
# Processing Record 46 |  Iowa
# Processing Record 47 |  Juneau
# Processing Record 48 |  La crosse
# Processing Record 49 |  Lafayette
# Processing Record 50 |  Monroe
# Processing Record 51 |  Richland
# Processing Record 52 |  Rock
# 52 |  Rock has missing data.
# Processing Record 53 |  Sauk
# 53 |  Sauk has missing data.
# Processing Record 54 |  Vernon districts (Wisconsin province)
# 54 |  Vernon districts (Wisconsin province) has missing data.
# Processing Record 55 | Granite Falls city (Yellow Medicine
# 55 | Granite Falls city (Yellow Medicine has missing data.
# Processing Record 56 |  Minnesota province)
# 56 |  Minnesota province) has missing data.
# Processing Record 57 | Xenia city (Greene district
# 57 | Xenia city (Greene district has missing data.
# Processing Record 58 |  Ohio province)
# 58 |  Ohio province) has missing data.
# Processing Record 59 | Buffalo city (Erie district
# 59 | Buffalo city (Erie district has missing data.
# Processing Record 60 |  New York province)
# 60 |  New York province) has missing data.
# Processing Record 61 | Anderson
# Processing Record 62 |  Benton
# Processing Record 63 |  Cheatham
# 63 |  Cheatham has missing data.
# Processing Record 64 |  Davidson
# Processing Record 65 |  Henry
# Processing Record 66 |  Hickman
# Processing Record 67 |  Houston
# Processing Record 68 |  Jackson
# Processing Record 69 |  Knox
# Processing Record 70 |  Lake
# Processing Record 71 |  Obion
# Processing Record 72 |  Perry
# Processing Record 73 |  Pickett
# 73 |  Pickett has missing data.
# Processing Record 74 |  Stewart districts (Tennessee province)
# 74 |  Stewart districts (Tennessee province) has missing data.
# Processing Record 75 | Near Yountville city (Napa district
# 75 | Near Yountville city (Napa district has missing data.
# Processing Record 76 |  California province)
# 76 |  California province) has missing data.
# Processing Record 77 | Franklin
# Processing Record 78 |  Jefferson districts (Missouri province)
# 78 |  Jefferson districts (Missouri province) has missing data.
# Processing Record 79 | Oklahoma province
# 79 | Oklahoma province has missing data.
# Processing Record 80 | Maui district (Hawaii province)
# 80 | Maui district (Hawaii province) has missing data.
# Processing Record 81 | Tuscaloosa district (Alabama province)
# 81 | Tuscaloosa district (Alabama province) has missing data.
# Processing Record 82 |  Connecticut
# Processing Record 83 |  Florida
# Processing Record 84 |  Georgia
# Processing Record 85 |  Massachusetts
# Processing Record 86 |  Mississippi
# Processing Record 87 |  Norh Carolina
# 87 |  Norh Carolina has missing data.
# Processing Record 88 |  New Jersey
# Processing Record 89 |  New York
# Processing Record 90 |  Pennsylvania
# Processing Record 91 |  Rhode Island provinces
# 91 |  Rhode Island provinces has missing data.
# Processing Record 92 | Miami-Dade
# 92 | Miami-Dade has missing data.
# Processing Record 93 |  Monroe
# Processing Record 94 |  Broward
# 94 |  Broward has missing data.
# Processing Record 95 |  Collier districts (Florida province)
# 95 |  Collier districts (Florida province) has missing data.
# Processing Record 96 | Texas
# Processing Record 97 |  Louisiana
# Processing Record 98 |  Alabama provinces
# 98 |  Alabama provinces has missing data.
# Processing Record 99 | Gainesville
# Processing Record 100 |  Alachua areas (Alachua district
# 100 |  Alachua areas (Alachua district has missing data.
# Processing Record 101 |  Florida province)
# 101 |  Florida province) has missing data.
# Processing Record 102 |  Lafayette
# Processing Record 103 |  Gulf districts (Florida province)
# 103 |  Gulf districts (Florida province) has missing data.
# Processing Record 104 | Los Alamos
# Processing Record 105 |  Rio Arriba
# 105 |  Rio Arriba has missing data.
# Processing Record 106 |  Sandoval
# Processing Record 107 |  Santa Fe districts (New Mexico province)
# 107 |  Santa Fe districts (New Mexico province) has missing data.
# Processing Record 108 | Sarasota district (Florida province)
# 108 | Sarasota district (Florida province) has missing data.
# Processing Record 109 | Park
# Processing Record 110 |  Jefferson
# Processing Record 111 |  Larimer districts (Colorado province)
# 111 |  Larimer districts (Colorado province) has missing data.
# Processing Record 112 | Hanford area (Benton district
# 112 | Hanford area (Benton district has missing data.
# Processing Record 113 |  Washington province)
# 113 |  Washington province) has missing data.
# Processing Record 114 | Alaska province
# 114 | Alaska province has missing data.
# Processing Record 115 | Arizona
# Processing Record 116 |  California
# Processing Record 117 |  Colorado
# Processing Record 118 |  Idaho
# Processing Record 119 |  Montana
# Processing Record 120 |  Nevada
# Processing Record 121 |  New Mexico
# Processing Record 122 |  Oregon
# Processing Record 123 |  South Dakota
# Processing Record 124 |  Texas
# Processing Record 125 |  Utah
# Processing Record 126 |  Washington
# Processing Record 127 |  Wyoming
# Processing Record 128 |  Florida
# Processing Record 129 |  North Dakota provinces
# 129 |  North Dakota provinces has missing data.
# Processing Record 130 | South Carolina
# Processing Record 131 |  Georgia
# Processing Record 132 |  Alabama
# Processing Record 133 |  Florida
# Processing Record 134 |  Louisiana
# Processing Record 135 |  Texas provinces
# 135 |  Texas provinces has missing data.
# Processing Record 136 | Liberty district (Texas province)
# 136 | Liberty district (Texas province) has missing data.
# Processing Record 137 | Franklin
# Processing Record 138 |  Jefferson
# Processing Record 139 |  Gasconade districts (Missouri province)
# 139 |  Gasconade districts (Missouri province) has missing data.
# Processing Record 140 | Pennsylvania province
# 140 | Pennsylvania province has missing data.
# Processing Record 141 | New Hampshire
# Processing Record 142 |  Vermont
# Processing Record 143 |  Maine
# Processing Record 144 |  Massachusetts
# Processing Record 145 |  Rhode Island provinces
# 145 |  Rhode Island provinces has missing data.
# Processing Record 146 | Virginia province
# 146 | Virginia province has missing data.
# Processing Record 147 | Kearny
# Processing Record 148 |  Trego
# 148 |  Trego has missing data.
# Processing Record 149 |  Ellis
# Processing Record 150 |  Rooks
# 150 |  Rooks has missing data.
# Processing Record 151 |  Ford
# Processing Record 152 |  Osborne
# Processing Record 153 |  Smith
# Processing Record 154 |  Jewell
# Processing Record 155 |  Edwards
# Processing Record 156 |  Republic
# Processing Record 157 |  Washington districts (Kansas province)
# 157 |  Washington districts (Kansas province) has missing data.
# Processing Record 158 |  Union city (Franklin district
# 158 |  Union city (Franklin district has missing data.
# Processing Record 159 |  Missouri province)
# 159 |  Missouri province) has missing data.
# Processing Record 160 |  Johnson
# Processing Record 161 |  Pettis
# 161 |  Pettis has missing data.
# Processing Record 162 |  Cooper
# Processing Record 163 |  Callaway
# Processing Record 164 |  St Charles
# 164 |  St Charles has missing data.
# Processing Record 165 |  Gentry
# Processing Record 166 |  Worth
# Processing Record 167 |  Clark
# Processing Record 168 |  Madison districts (Missouri)
# 168 |  Madison districts (Missouri) has missing data.
# Processing Record 169 |  Beaver
# Processing Record 170 |  Pontotoc
# Processing Record 171 |  Coal
# 171 |  Coal has missing data.
# Processing Record 172 |  Johnston
# Processing Record 173 |  Atoka
# Processing Record 174 |  Haskell
# Processing Record 175 |  Pottawatomie districts (Oklahoma province)
# 175 |  Pottawatomie districts (Oklahoma province) has missing data.
# Processing Record 176 |  Wichita
# Processing Record 177 |  Cooke
# 177 |  Cooke has missing data.
# Processing Record 178 |  Carson
# Processing Record 179 |  Hutchinson
# Processing Record 180 |  Hansford
# 180 |  Hansford has missing data.
# Processing Record 181 |  Wheeler districts (Texas province)
# 181 |  Wheeler districts (Texas province) has missing data.
# Processing Record 182 |  Thayer
# Processing Record 183 |  Gage
# 183 |  Gage has missing data.
# Processing Record 184 |  Sarpy
# 184 |  Sarpy has missing data.
# Processing Record 185 |  Webster
# Processing Record 186 |  Nuckolls districts (Nebraska province)
# 186 |  Nuckolls districts (Nebraska province) has missing data.
# Processing Record 187 |  Mills
# Processing Record 188 |  Pottawattamie
# 188 |  Pottawattamie has missing data.
# Processing Record 189 |  Guthrie
# Processing Record 190 |  Boone
# Processing Record 191 |  Hamilton
# Processing Record 192 |  Wapello
# Processing Record 193 |  Johnson
# Processing Record 194 |  Black Hawk
# 194 |  Black Hawk has missing data.
# Processing Record 195 |  Benton
# Processing Record 196 |  Fayette
# Processing Record 197 |  Webster
# Processing Record 198 |  Ringgold districts (Iowa province)
# 198 |  Ringgold districts (Iowa province) has missing data.
# Processing Record 199 |  Madison district (Illinois province)
# 199 |  Madison district (Illinois province) has missing data.
# Processing Record 200 | Watkins area (Adams district
# 200 | Watkins area (Adams district has missing data.
# Processing Record 201 |  Colorado province)
# 201 |  Colorado province) has missing data.
# Processing Record 202 | Texas
# Processing Record 203 |  Mississippi
# Processing Record 204 |  Louisiana
# Processing Record 205 |  Florida
# Processing Record 206 |  Pennsylvania
# Processing Record 207 |  South Carolina
# Processing Record 208 |  North Carolina
# Processing Record 209 |  Georgia
# Processing Record 210 |  Pensylvania
# 210 |  Pensylvania has missing data.
# Processing Record 211 |  New Jersey
# Processing Record 212 |  Virginia
# Processing Record 213 |  Iowa provinces
# 213 |  Iowa provinces has missing data.
# Processing Record 214 | Virginia
# Processing Record 215 |  New Jersey
# Processing Record 216 |  Pennsylvania
# Processing Record 217 |  North Carolina
# Processing Record 218 |  West Virginia
# Processing Record 219 |  Maryland provinces
# 219 |  Maryland provinces has missing data.
# Processing Record 220 | Calhoun
# Processing Record 221 |  Lee
# Processing Record 222 |  Pontotoc
# Processing Record 223 |  Prentiss
# Processing Record 224 |  Union districts (Mississippi province)
# 224 |  Union districts (Mississippi province) has missing data.
# Processing Record 225 | Marion
# Processing Record 226 |  Clay districts (Florida province)
# 226 |  Clay districts (Florida province) has missing data.
# Processing Record 227 | Hoisington city (Barton district
# 227 | Hoisington city (Barton district has missing data.
# Processing Record 228 |  Kansas province)
# 228 |  Kansas province) has missing data.
# Processing Record 229 | Blue Grass
# Processing Record 230 |  Bettendorf cities (Scott district
# 230 |  Bettendorf cities (Scott district has missing data.
# Processing Record 231 |  Iowa province)
# 231 |  Iowa province) has missing data.
# Processing Record 232 |  Leon city (Decatur district
# 232 |  Leon city (Decatur district has missing data.
# Processing Record 233 |  Iowa province)
# 233 |  Iowa province) has missing data.
# Processing Record 234 | Siren city (Burnett district
# 234 | Siren city (Burnett district has missing data.
# Processing Record 235 |  Wisconsin province)
# 235 |  Wisconsin province) has missing data.
# Processing Record 236 | Brainerd city (Crow King district
# 236 | Brainerd city (Crow King district has missing data.
# Processing Record 237 |  Minnesota province)
# 237 |  Minnesota province) has missing data.
# Processing Record 238 | Cordell city (Washita district
# 238 | Cordell city (Washita district has missing data.
# Processing Record 239 |  Oklahoma province)
# 239 |  Oklahoma province) has missing data.
# Processing Record 240 |  Polk
# 240 |  Polk has missing data.
# Processing Record 241 |  Merrick
# Processing Record 242 |  Hamilton districts (Nebraska province)
# 242 |  Hamilton districts (Nebraska province) has missing data.
# Processing Record 243 | Howard
# Processing Record 244 |  Prince George's districts (Maryland province)
# 244 |  Prince George's districts (Maryland province) has missing data.
# Processing Record 245 | Pasadena city (Harris district
# 245 | Pasadena city (Harris district has missing data.
# Processing Record 246 |  Texas province)
# 246 |  Texas province) has missing data.
# Processing Record 247 | Hondo city (Medina district
# 247 | Hondo city (Medina district has missing data.
# Processing Record 248 |  Texas province)
# 248 |  Texas province) has missing data.
# Processing Record 249 | Jakson town (Dakota district
# 249 | Jakson town (Dakota district has missing data.
# Processing Record 250 |  Nebraska province)
# 250 |  Nebraska province) has missing data.
# Processing Record 251 | Seattle city (King district)
# 251 | Seattle city (King district) has missing data.
# Processing Record 252 |  Tacoma city (Pierce district)
# 252 |  Tacoma city (Pierce district) has missing data.
# Processing Record 253 |  Olympia city (Thurston district) (Washington province)
# 253 |  Olympia city (Thurston district) (Washington province) has missing data.
# Processing Record 254 | Cleveland area (Henry district
# 254 | Cleveland area (Henry district has missing data.
# Processing Record 255 |  Illinois province)
# 255 |  Illinois province) has missing data.
# Processing Record 256 |  Barstow
# Processing Record 257 |  Osborn areas (Rock Island district
# 257 |  Osborn areas (Rock Island district has missing data.
# Processing Record 258 |  Illinois province)
# 258 |  Illinois province) has missing data.
# Processing Record 259 | Minnesota
# Processing Record 260 |  Iowa
# Processing Record 261 |  Wisconsin
# Processing Record 262 |  Illinois provinces
# 262 |  Illinois provinces has missing data.
# Processing Record 263 | Texas province
# 263 | Texas province has missing data.
# Processing Record 264 | Illinois
# Processing Record 265 |  Indiana
# Processing Record 266 |  Iowa
# Processing Record 267 |  Kansas
# Processing Record 268 |  Michigan
# Processing Record 269 |  Minnesota
# Processing Record 270 |  Missouri
# Processing Record 271 |  Nebraska
# Processing Record 272 |  North Dakota
# Processing Record 273 |  Ohio
# Processing Record 274 |  South Dakota
# Processing Record 275 |  Wisconsin provinces
# 275 |  Wisconsin provinces has missing data.
# Processing Record 276 | Florida province
# 276 | Florida province has missing data.
# Processing Record 277 | Oregon
# Processing Record 278 |  Washington
# Processing Record 279 |  Idaho
# Processing Record 280 |  California
# Processing Record 281 |  Nevada
# Processing Record 282 |  Colorado
# Processing Record 283 |  Arizona
# Processing Record 284 |  Wyoming
# Processing Record 285 |  Texas
# Processing Record 286 |  Oklahoma provinces
# 286 |  Oklahoma provinces has missing data.
# Processing Record 287 | Tennessee
# Processing Record 288 |  Kentucky
# Processing Record 289 |  West Virginia
# Processing Record 290 |  Virginia
# Processing Record 291 |  Georgia provinces
# 291 |  Georgia provinces has missing data.
# Processing Record 292 | Tennesse
# 292 | Tennesse has missing data.
# Processing Record 293 |  Kentucky provinces
# 293 |  Kentucky provinces has missing data.
# Processing Record 294 | District of Columbia province
# 294 | District of Columbia province has missing data.
# Processing Record 295 | Sevier
# Processing Record 296 |  Blount
# 296 |  Blount has missing data.
# Processing Record 297 |  Knox
# Processing Record 298 |  Hawkins districts (Tennessee province)
# 298 |  Hawkins districts (Tennessee province) has missing data.
# Processing Record 299 |  Cumberland
# Processing Record 300 |  Bell districts (Kentucky province)
# 300 |  Bell districts (Kentucky province) has missing data.
# Processing Record 301 |  Wise
# Processing Record 302 |  Smyth
# 302 |  Smyth has missing data.
# Processing Record 303 |  Washington districts (Virginia province)
# 303 |  Washington districts (Virginia province) has missing data.
# Processing Record 304 |  Cabell district (West Virginia province)
# 304 |  Cabell district (West Virginia province) has missing data.
# Processing Record 305 |  North Carolina
# Processing Record 306 |  Mississippi
# Processing Record 307 |  Arkansas
# Processing Record 308 |  Texas provinces
# 308 |  Texas provinces has missing data.
# Processing Record 309 | St. Tammany
# 309 | St. Tammany has missing data.
# Processing Record 310 |  Terrebonne
# Processing Record 311 |  Lafayette
# Processing Record 312 |  Acadia
# 312 |  Acadia has missing data.
# Processing Record 313 |  Evangeline
# 313 |  Evangeline has missing data.
# Processing Record 314 |  Rapides districts (Louisiana province)
# 314 |  Rapides districts (Louisiana province) has missing data.
# Processing Record 315 | Alabama
# Processing Record 316 |  Louisiana
# Processing Record 317 |  Virginia
# Processing Record 318 |  North Carolina
# Processing Record 319 |  South Carolina
# Processing Record 320 |  Mississipi
# 320 |  Mississipi has missing data.
# Processing Record 321 |  Georgia
# Processing Record 322 |  Pensylvania
# 322 |  Pensylvania has missing data.
# Processing Record 323 |
# 323 |  has missing data.
# Processing Record 324 | Oklahoma
# Processing Record 325 |  Missouri
# Processing Record 326 |  Wisconsin
# Processing Record 327 |  Michigan
# Processing Record 328 |  Arkansas provinces
# 328 |  Arkansas provinces has missing data.
# Processing Record 329 | Happy town (Randall
# 329 | Happy town (Randall has missing data.
# Processing Record 330 |  Swisher districts
# 330 |  Swisher districts has missing data.
# Processing Record 331 |  Texas province)
# 331 |  Texas province) has missing data.
# Processing Record 332 | Wayne
# Processing Record 333 |  Jefferson districts (Illinois province)
# 333 |  Jefferson districts (Illinois province) has missing data.
# Processing Record 334 | Breckinridge
# Processing Record 335 |  Meade
# Processing Record 336 |  Crittenden
# Processing Record 337 |  Webster
# Processing Record 338 |  Hopkins
# Processing Record 339 |  Ohio
# Processing Record 340 |  Hardin
# Processing Record 341 |  Edmonson districts (Kentucky province)
# 341 |  Edmonson districts (Kentucky province) has missing data.
# Processing Record 342 |  Bollinger
# 342 |  Bollinger has missing data.
# Processing Record 343 |  Howell districts (Missouri province)
# 343 |  Howell districts (Missouri province) has missing data.
# Processing Record 344 |  Charles
# 344 |  Charles has missing data.
# Processing Record 345 |  Calvert
# Processing Record 346 |  Dorchester
# Processing Record 347 |  Wicomico
# 347 |  Wicomico has missing data.
# Processing Record 348 |  Cecil districts (Maryland province)
# 348 |  Cecil districts (Maryland province) has missing data.
# Processing Record 349 |  Illinois (Clay
# 349 |  Illinois (Clay has missing data.
# Processing Record 350 | Union
# Processing Record 351 |  Johnson
# Processing Record 352 | Pope
# Processing Record 353 |  Moultrie
# Processing Record 354 |  Saline
# Processing Record 355 |  Bond)
# 355 |  Bond) has missing data.
# Processing Record 356 |  Gordon district (Georgia province)
# 356 |  Gordon district (Georgia province) has missing data.
# Processing Record 357 |  Atchison district (Kansas province)
# 357 |  Atchison district (Kansas province) has missing data.
# Processing Record 358 |  Erie
# Processing Record 359 |  Allegany districts (New York province)
# 359 |  Allegany districts (New York province) has missing data.
# Processing Record 360 |  Stark district (Ohio province)
# 360 |  Stark district (Ohio province) has missing data.
# Processing Record 361 |  Indiana
# Processing Record 362 |  Mercer
# Processing Record 363 |  Venango
# 363 |  Venango has missing data.
# Processing Record 364 |  Butler
# Processing Record 365 |  Armstrong
# Processing Record 366 |  Columbia
# Processing Record 367 |  Lebanon
# Processing Record 368 |  Allegheny districts (Pennsylvania province)
# 368 |  Allegheny districts (Pennsylvania province) has missing data.
# Processing Record 369 |  Rutherford
# Processing Record 370 |  Lake
# Processing Record 371 |  Henry
# Processing Record 372 |  Carter districts (Tennessee province)
# 372 |  Carter districts (Tennessee province) has missing data.
# Processing Record 373 |  Virginia (Shenandoah
# 373 |  Virginia (Shenandoah has missing data.
# Processing Record 374 |  Greensville
# 374 |  Greensville has missing data.
# Processing Record 375 |  Bedford
# Processing Record 376 |  (Campbell
# 376 |  (Campbell has missing data.
# Processing Record 377 |  Nottoway
# 377 |  Nottoway has missing data.
# Processing Record 378 |  Prince George)
# 378 |  Prince George) has missing data.
# Processing Record 379 |  Marshall district (West Virginia province)
# 379 |  Marshall district (West Virginia province) has missing data.
# Processing Record 380 |  Pontotoc
# Processing Record 381 |  Chickasaw districts (Mississippi province)
# 381 |  Chickasaw districts (Mississippi province) has missing data.
# Processing Record 382 |  Perry district (Indiana province)
# 382 |  Perry district (Indiana province) has missing data.
# Processing Record 383 | Ladysmith city (Rusk district
# 383 | Ladysmith city (Rusk district has missing data.
# Processing Record 384 |  Wisconsin province)
# 384 |  Wisconsin province) has missing data.
# Processing Record 385 | Tipton
# Processing Record 386 |  Carroll
# Processing Record 387 |  Montgomery
# Processing Record 388 |  Sumner
# Processing Record 389 |  Bedford
# Processing Record 390 |  Coffee
# 390 |  Coffee has missing data.
# Processing Record 391 |  Morgan
# Processing Record 392 |  Cumberland
# Processing Record 393 |  Anderson districts (Tennessee province)
# 393 |  Anderson districts (Tennessee province) has missing data.
# Processing Record 394 |  Henry
# Processing Record 395 |  Dale
# Processing Record 396 |  Fayette
# Processing Record 397 |  Walker
# Processing Record 398 |  Winston
# Processing Record 399 |  Lamar
# Processing Record 400 |  Cullman
# Processing Record 401 |  Tuscaloosa
# Processing Record 402 |  Jefferson
# Processing Record 403 |  Cherokee districts (Alabama province)
# 403 |  Cherokee districts (Alabama province) has missing data.
# Processing Record 404 |  Van Wert
# Processing Record 405 |  Paulding
# Processing Record 406 |  Putnam
# Processing Record 407 |  Defiance
# Processing Record 408 |  Athens
# Processing Record 409 |  Logan
# Processing Record 410 |  Union
# Processing Record 411 |  Seneca
# Processing Record 412 |  Ottawa districts (Ohio province)
# 412 |  Ottawa districts (Ohio province) has missing data.
# Processing Record 413 |  Allen district (Kentucky province)
# 413 |  Allen district (Kentucky province) has missing data.
# Processing Record 414 |  Cross
# 414 |  Cross has missing data.
# Processing Record 415 |  Crittenden
# Processing Record 416 |  Mississippi districts (Arkansas province)
# 416 |  Mississippi districts (Arkansas province) has missing data.
# Processing Record 417 |  Appling
# Processing Record 418 |  Cherokee
# Processing Record 419 |  Pickens
# Processing Record 420 |  Dawson
# Processing Record 421 |  Atkinson
# Processing Record 422 |  Coffee districts (Georgia province)
# 422 |  Coffee districts (Georgia province) has missing data.
# Processing Record 423 |  Blackford district (Indiana province)
# 423 |  Blackford district (Indiana province) has missing data.
# Processing Record 424 |  Lowndes
# 424 |  Lowndes has missing data.
# Processing Record 425 |  Winston
# Processing Record 426 |  Noxubee
# 426 |  Noxubee has missing data.
# Processing Record 427 |  Oktibbeha districts (Mississippi province)
# 427 |  Oktibbeha districts (Mississippi province) has missing data.
# Processing Record 428 |  Mercer district (Pennsylvania province)
# 428 |  Mercer district (Pennsylvania province) has missing data.
# Processing Record 429 |  McCormick district (South Carolina province)
# 429 |  McCormick district (South Carolina province) has missing data.
# Processing Record 430 | Washington DC (District of Columbia district
# 430 | Washington DC (District of Columbia district has missing data.
# Processing Record 431 |  District of Columbia province)
# 431 |  District of Columbia province) has missing data.
# Processing Record 432 |  North Carolina
# Processing Record 433 |  South Carolina
# Processing Record 434 |  Virginia
# Processing Record 435 |  New York
# Processing Record 436 |  Pennsylvania
# Processing Record 437 |  Kentucky
# Processing Record 438 |  New Jersey
# Processing Record 439 |  Maryland
# Processing Record 440 |  Missouri
# Processing Record 441 |  Tennesse provinces
# 441 |  Tennesse provinces has missing data.
# Processing Record 442 | Oklahoma
# Processing Record 443 |  Massachusetts
# Processing Record 444 |  New York
# Processing Record 445 |  Arkansas
# Processing Record 446 |  Missouri
# Processing Record 447 |  New Mexico
# Processing Record 448 |  Louisiana
# Processing Record 449 |  Texas provinces
# 449 |  Texas provinces has missing data.
# Processing Record 450 | Tennessee
# Processing Record 451 |  Virginia
# Processing Record 452 |  Kentucky
# Processing Record 453 |  Ohio
# Processing Record 454 |  Arkansas
# Processing Record 455 |  Oklahoma
# Processing Record 456 |  Texas provinces
# 456 |  Texas provinces has missing data.
# Processing Record 457 | Pike district (Kentucky province)
# 457 | Pike district (Kentucky province) has missing data.
# Processing Record 458 |  Virginia province
# 458 |  Virginia province has missing data.
# Processing Record 459 | Comal
# Processing Record 460 |  Guadalupe
# Processing Record 461 |  Bandera
# Processing Record 462 |  Uvalde
# Processing Record 463 |  McMullen
# 463 |  McMullen has missing data.
# Processing Record 464 |  Taylor districts (Texas province)
# 464 |  Taylor districts (Texas province) has missing data.
# Processing Record 465 | Georgia province
# 465 | Georgia province has missing data.
# Processing Record 466 | Louisiane
# Processing Record 467 |  Mississippi
# Processing Record 468 |  Alabama
# Processing Record 469 |  Tennessee provinces
# 469 |  Tennessee provinces has missing data.
# Processing Record 470 | Arizona province
# 470 | Arizona province has missing data.
# Processing Record 471 | Fallbrok area (San Diego district
# 471 | Fallbrok area (San Diego district has missing data.
# Processing Record 472 |  Californie province)
# 472 |  Californie province) has missing data.
# Processing Record 473 | Lincoln district (New Mexico province)
# 473 | Lincoln district (New Mexico province) has missing data.
# Processing Record 474 | Georgia
# Processing Record 475 |  Alaska provinces
# 475 |  Alaska provinces has missing data.
# Processing Record 476 | Colorado province
# 476 | Colorado province has missing data.
# Processing Record 477 | Arizona province
# 477 | Arizona province has missing data.
# Processing Record 478 | Claremont
# Processing Record 479 |  Glendora
# Processing Record 480 |  La Verne areas (Los Angeles district
# 480 |  La Verne areas (Los Angeles district has missing data.
# Processing Record 481 |  California province))
# 481 |  California province)) has missing data.
# Processing Record 482 | Oregon province
# 482 | Oregon province has missing data.
# Processing Record 483 | Arizona province
# 483 | Arizona province has missing data.
# Processing Record 484 | Alabama
# Processing Record 485 |  district of Columbia
# Processing Record 486 |  Illinois
# Processing Record 487 |  Indiana
# Processing Record 488 |  Louisiana
# Processing Record 489 |  Mississippi
# Processing Record 490 |  Texas
# Processing Record 491 |  Florida
# Processing Record 492 |  Massachusetts
# Processing Record 493 |  Missouri
# Processing Record 494 |  New York City
# 494 |  New York City has missing data.
# Processing Record 495 |  Ohio
# Processing Record 496 |  Georgia
# Processing Record 497 |  Kentucky
# Processing Record 498 |  Maryland
# Processing Record 499 |  Michigan
# Processing Record 500 |  Nebraska
# Processing Record 501 |  South Dacota
# 501 |  South Dacota has missing data.
# Processing Record 502 |  Tennessee
# Processing Record 503 |  Texas
# Processing Record 504 |  Virginia
# Processing Record 505 |  Wisconsin
# Processing Record 506 | Alabama
# Processing Record 507 |  California
# Processing Record 508 |  Connecticut
# Processing Record 509 |  Georgia
# Processing Record 510 |  Hawaii
# Processing Record 511 |  Illinois
# Processing Record 512 |  Kansas
# Processing Record 513 |  Maine
# Processing Record 514 |  Massachusetts
# Processing Record 515 |  Michigan
# Processing Record 516 |  Missouri
# Processing Record 517 |  Mississippi
# Processing Record 518 |  Minnesota
# Processing Record 519 |  New Jersey
# Processing Record 520 |  New Mexico
# Processing Record 521 |  North Carolina
# Processing Record 522 |  New York
# Processing Record 523 |  Pennsylvannia
# 523 |  Pennsylvannia has missing data.
# Processing Record 524 |  Rhode Island
# Processing Record 525 |  Texas
# Processing Record 526 |  Utah
# Processing Record 527 |  Virginia
# Processing Record 528 |  Wisconsin
# Processing Record 529 | Illinois
# Processing Record 530 |  Indiana
# Processing Record 531 |  Iowa
# Processing Record 532 |  Kansas
# Processing Record 533 |  Michigan
# Processing Record 534 |  Minnesota
# Processing Record 535 |  Missouri
# Processing Record 536 |  Nebraska
# Processing Record 537 |  North Dakota
# Processing Record 538 |  Ohio
# Processing Record 539 |  South Dakota
# Processing Record 540 |  Wisconsin provinces
# 540 |  Wisconsin provinces has missing data.
# Processing Record 541 | Cleveland
# Processing Record 542 |  Comanche
# Processing Record 543 |  Creek
# 543 |  Creek has missing data.
# Processing Record 544 |  Garvin
# Processing Record 545 |  Grady
# 545 |  Grady has missing data.
# Processing Record 546 |  Greer
# Processing Record 547 |  Harmon
# Processing Record 548 |  Jackson
# Processing Record 549 |  Kiowa
# Processing Record 550 |  Lincoln
# Processing Record 551 |  McClain
# 551 |  McClain has missing data.
# Processing Record 552 |  Nowata
# Processing Record 553 |  Pottawatomie
# 553 |  Pottawatomie has missing data.
# Processing Record 554 |  Rogers
# Processing Record 555 |  Stephens
# 555 |  Stephens has missing data.
# Processing Record 556 |  Tillman
# 556 |  Tillman has missing data.
# Processing Record 557 |  Tulsa
# Processing Record 558 |  Alfalfa
# 558 |  Alfalfa has missing data.
# Processing Record 559 |  Beaver
# Processing Record 560 |  Beckham
# 560 |  Beckham has missing data.
# Processing Record 561 |  Blaine
# Processing Record 562 |  Caddo
# Processing Record 563 |  Canadian
# Processing Record 564 |  Cimarron
# Processing Record 565 |  Custer
# Processing Record 566 |  Dewey
# Processing Record 567 |  Ellis
# Processing Record 568 |  Garfield
# Processing Record 569 |  Grant
# Processing Record 570 |  Harper
# Processing Record 571 |  Kay
# 571 |  Kay has missing data.
# Processing Record 572 |  Kingfisher
# Processing Record 573 |  Logan
# Processing Record 574 |  Major
# 574 |  Major has missing data.
# Processing Record 575 |  Noble
# Processing Record 576 |  Oklahoma
# Processing Record 577 |  Osage
# Processing Record 578 |  Pawnee
# Processing Record 579 |  Payne
# Processing Record 580 |  Roger Mills
# 580 |  Roger Mills has missing data.
# Processing Record 581 |  Texas
# Processing Record 582 |  Washington
# Processing Record 583 |  Washita
# 583 |  Washita has missing data.
# Processing Record 584 |  Woods
# 584 |  Woods has missing data.
# Processing Record 585 |  Woodward districts (Oklahoma province)
# 585 |  Woodward districts (Oklahoma province) has missing data.
# Processing Record 586 |  Missouri
# Processing Record 587 |  Kansas
# Processing Record 588 |  New York
# Processing Record 589 |  Indiana
# Processing Record 590 |  Ohio provinces
# 590 |  Ohio provinces has missing data.
# Processing Record 591 | Marin
# Processing Record 592 |  Los Angeles
# Processing Record 593 |  Santa Cruz districts (California province)
# 593 |  Santa Cruz districts (California province) has missing data.
# Processing Record 594 |  Oregon
# Processing Record 595 |  Nevada provinces
# 595 |  Nevada provinces has missing data.
# Processing Record 596 | Fulton
# Processing Record 597 |  Tioga
# Processing Record 598 |  Broome
# Processing Record 599 |  Oswego
# Processing Record 600 |  Delaware
# Processing Record 601 |  Dutchess districts (New York province)
# 601 |  Dutchess districts (New York province) has missing data.
# Processing Record 602 |  Wayne district (Pennsylvania province)
# 602 |  Wayne district (Pennsylvania province) has missing data.
# Processing Record 603 |  Connecticut
# Processing Record 604 |  Massachusetts
# Processing Record 605 |  Michigan
# Processing Record 606 |  New Hampshire
# Processing Record 607 |  New Jersey
# Processing Record 608 |  Ohio
# Processing Record 609 |  Wisconsin provinces
# 609 |  Wisconsin provinces has missing data.
# Processing Record 610 | Delaware
# Processing Record 611 |  Kentucky
# Processing Record 612 |  Massachusetts
# Processing Record 613 |  Maryland
# Processing Record 614 |  North Carolina
# Processing Record 615 |  New Hampshire
# Processing Record 616 |  New Jersey
# Processing Record 617 |  New York
# Processing Record 618 |  District of Columbia
# Processing Record 619 |  Ohio
# Processing Record 620 |  Pennsylvania
# Processing Record 621 |  Rhode Island
# Processing Record 622 |  Tennessee
# Processing Record 623 |  Virginia
# Processing Record 624 |  Vermont
# Processing Record 625 |  West Virginia
# Processing Record 626 |  Illinois
# Processing Record 627 |  Missouri
# Processing Record 628 |  Iowa
# Processing Record 629 |  Nebraska
# Processing Record 630 |  Connecticut provinces
# 630 |  Connecticut provinces has missing data.
# Processing Record 631 | West Virginia
# Processing Record 632 |  Tennessee
# Processing Record 633 |  Kentucky
# Processing Record 634 |  Pennsylvania
# Processing Record 635 |  North Carolina
# Processing Record 636 |  Virginia provinces
# 636 |  Virginia provinces has missing data.
# Processing Record 637 | Mitchell
# Processing Record 638 |  Worth districts (Georgia province)
# 638 |  Worth districts (Georgia province) has missing data.
# Processing Record 639 |  Jackson district (Alabama province) North Carolina
# 639 |  Jackson district (Alabama province) North Carolina has missing data.
# Processing Record 640 |  South Carolina
# Processing Record 641 |  Tennessee provinces
# 641 |  Tennessee provinces has missing data.
# Processing Record 642 | Alabama
# Processing Record 643 |  Illinois
# Processing Record 644 |  Indiana
# Processing Record 645 |  Louisiana
# Processing Record 646 |  Michigan
# Processing Record 647 |  Missouri
# Processing Record 648 |  Mississippi
# Processing Record 649 |  New York
# Processing Record 650 |  Tennessee
# Processing Record 651 | Texas
# Processing Record 652 |  Pennsylvania
# Processing Record 653 |  Nebraska
# Processing Record 654 |  Wisconsin provinces
# 654 |  Wisconsin provinces has missing data.
# Processing Record 655 | Allen
# Processing Record 656 |  Carroll
# Processing Record 657 |  Adams
# Processing Record 658 |  Cass
# Processing Record 659 |  Howard
# Processing Record 660 |  Tipton
# Processing Record 661 |  Wells
# Processing Record 662 |  Miami
# Processing Record 663 |  Boone
# Processing Record 664 |  Jennings
# Processing Record 665 |  Clay
# Processing Record 666 |  Tippecanoe
# 666 |  Tippecanoe has missing data.
# Processing Record 667 |  Huntington
# Processing Record 668 |  Decatur districts (Indiana province)
# 668 |  Decatur districts (Indiana province) has missing data.
# Processing Record 669 |  Allen
# Processing Record 670 |  Auglaize
# 670 |  Auglaize has missing data.
# Processing Record 671 |  Van Wert
# Processing Record 672 |  Darke
# 672 |  Darke has missing data.
# Processing Record 673 |  Mercer
# Processing Record 674 |  Miami districts (Ohio province)
# 674 |  Miami districts (Ohio province) has missing data.
# Processing Record 675 |  Mercer
# Processing Record 676 |  Shelby
# Processing Record 677 |  Logan
# Processing Record 678 |  Hamilton
# Processing Record 679 |  Winnebago districts (Illinois province)
# 679 |  Winnebago districts (Illinois province) has missing data.
# Processing Record 680 | North Carolina
# Processing Record 681 |  Maryland
# Processing Record 682 |  Virginia
# Processing Record 683 |  West Virginia
# Processing Record 684 |  Delaware
# Processing Record 685 |  Pennsylvania
# Processing Record 686 |  New Jersey
# Processing Record 687 |  District of Columbia provinces
# 687 |  District of Columbia provinces has missing data.
# Processing Record 688 | Orleans
# Processing Record 689 |  St. John the Baptist
# 689 |  St. John the Baptist has missing data.
# Processing Record 690 |  Terrebonne
# Processing Record 691 |  St. Tammany
# 691 |  St. Tammany has missing data.
# Processing Record 692 |  Tangipahoa districts (Louisiana province)
# 692 |  Tangipahoa districts (Louisiana province) has missing data.
# Processing Record 693 |  Hancock
# Processing Record 694 |  Harrison
# Processing Record 695 |  Jackson
# Processing Record 696 |  Pike
# 696 |  Pike has missing data.
# Processing Record 697 |  Walthall districts (Mississippi province)
# 697 |  Walthall districts (Mississippi province) has missing data.
# Processing Record 698 |  Bay district (Florida province)
# 698 |  Bay district (Florida province) has missing data.
# Processing Record 699 |  Mobile
# Processing Record 700 |  Baldwin
# Processing Record 701 |  Lee districts (Alabama province)
# 701 |  Lee districts (Alabama province) has missing data.
# Processing Record 702 |  Sumter
# Processing Record 703 |  Bulloch
# 703 |  Bulloch has missing data.
# Processing Record 704 |  Fulton
# Processing Record 705 |  DeKalb
# Processing Record 706 |  Cobb
# Processing Record 707 |  Clayton
# Processing Record 708 |  Gwinnett districts (Georgia province)
# 708 |  Gwinnett districts (Georgia province) has missing data.
# Processing Record 709 |  Wake district (North Carolina province)
# 709 |  Wake district (North Carolina province) has missing data.
# Processing Record 710 | Morgan
# Processing Record 711 |  Leslie
# Processing Record 712 |  Breathitt
# 712 |  Breathitt has missing data.
# Processing Record 713 |  Menifee districts (Kentucky province)
# 713 |  Menifee districts (Kentucky province) has missing data.
# Processing Record 714 |  Wayne
# Processing Record 715 |  Cabell
# 715 |  Cabell has missing data.
# Processing Record 716 |  Kanawha
# 716 |  Kanawha has missing data.
# Processing Record 717 |  Lincoln
# Processing Record 718 |  Mingo districts (West Virginia province)
# 718 |  Mingo districts (West Virginia province) has missing data.
# Processing Record 719 |  Dickenson
# 719 |  Dickenson has missing data.
# Processing Record 720 |  Tazewell
# Processing Record 721 |  Wise
# Processing Record 722 |  Buchanan districts (Virginia province)
# 722 |  Buchanan districts (Virginia province) has missing data.
# Processing Record 723 |  Alabama
# Processing Record 724 |  Connecticut
# Processing Record 725 |  Delaware
# Processing Record 726 |  Florida
# Processing Record 727 |  Georgia
# Processing Record 728 |  Massachusetts
# Processing Record 729 |  Maryland
# Processing Record 730 |  North Carolina
# Processing Record 731 |  New Hampshire
# Processing Record 732 |  New Jersey
# Processing Record 733 |  New York
# Processing Record 734 |  Pennsylvania
# Processing Record 735 |  Rhode Island
# Processing Record 736 |  South Carolina
# Processing Record 737 |  Tennessee
# Processing Record 738 |  Vermont provinces
# 738 |  Vermont provinces has missing data.
# Processing Record 739 | Denver
# Processing Record 740 |  Boulder districts (Colorado province)
# 740 |  Boulder districts (Colorado province) has missing data.
# Processing Record 741 |  Wyoming province
# 741 |  Wyoming province has missing data.
# Processing Record 742 | Pennsylvania
# Processing Record 743 |  Connecticut
# Processing Record 744 |  New York
# Processing Record 745 |  New Jersey
# Processing Record 746 |  Vermont
# Processing Record 747 |  Virginia
# Processing Record 748 |  Massachusetts
# Processing Record 749 |  Rhode Island provinces
# 749 |  Rhode Island provinces has missing data.
# Processing Record 750 | Colbert
# Processing Record 751 |  Lauderdale
# Processing Record 752 |  Limestone
# Processing Record 753 |  Madison
# Processing Record 754 |  Jackson
# Processing Record 755 |  Dekalb
# Processing Record 756 |  Lamar
# Processing Record 757 |  Walker
# Processing Record 758 | St Clair
# Processing Record 759 |  Talladega
# Processing Record 760 |  Shelby
# Processing Record 761 |  Clay districts (Alabama province)
# 761 |  Clay districts (Alabama province) has missing data.
# Processing Record 762 |  Mississippi
# Processing Record 763 |  Craighead
# 763 |  Craighead has missing data.
# Processing Record 764 |  White
# Processing Record 765 |  Woodruff
# Processing Record 766 |  Cross districts (Arkansas province)
# 766 |  Cross districts (Arkansas province) has missing data.
# Processing Record 767 |  Adams
# Processing Record 768 |  Weld
# 768 |  Weld has missing data.
# Processing Record 769 |  Morgan districts (Colorado province)
# 769 |  Morgan districts (Colorado province) has missing data.
# Processing Record 770 |  Cherokee
# Processing Record 771 |  Franklin
# Processing Record 772 |  Madison
# Processing Record 773 |  Elbert
# 773 |  Elbert has missing data.
# Processing Record 774 |  Hart
# Processing Record 775 |  Heard
# 775 |  Heard has missing data.
# Processing Record 776 |  Coweta districts (Georgia province)
# 776 |  Coweta districts (Georgia province) has missing data.
# Processing Record 777 |  Marion
# Processing Record 778 |  Mahaska
# 778 |  Mahaska has missing data.
# Processing Record 779 |  Lee
# Processing Record 780 |  Van Buren
# Processing Record 781 |  Jefferson
# Processing Record 782 |  Henry
# Processing Record 783 |  Louisa districts (Iowa province)
# 783 |  Louisa districts (Iowa province) has missing data.
# Processing Record 784 |  Adams
# Processing Record 785 |  Hancock
# Processing Record 786 |  Mc Donough
# 786 |  Mc Donough has missing data.
# Processing Record 787 |  Bureau
# 787 |  Bureau has missing data.
# Processing Record 788 |  Henry
# Processing Record 789 |  Brown
# 789 |  Brown has missing data.
# Processing Record 790 |  Mason
# Processing Record 791 |  Fulton
# Processing Record 792 |  Pope
# 792 |  Pope has missing data.
# Processing Record 793 |  Schuyler
# Processing Record 794 |  Sangamon
# 794 |  Sangamon has missing data.
# Processing Record 795 |  Pulaski
# Processing Record 796 |  Massac
# Processing Record 797 |  Alexander
# Processing Record 798 |  Jasper
# Processing Record 799 |  Mercer
# Processing Record 800 |  Warren
# Processing Record 801 |  Tazewell districts (Illinois province)
# 801 |  Tazewell districts (Illinois province) has missing data.
# Processing Record 802 |  Perry
# Processing Record 803 |  Kosciuscko
# 803 |  Kosciuscko has missing data.
# Processing Record 804 |  Putnam districts (Indiana province)
# 804 |  Putnam districts (Indiana province) has missing data.
# Processing Record 805 |  Crawford
# Processing Record 806 |  Wyandotte
# Processing Record 807 |  Leavenworth
# Processing Record 808 |  Neosho
# Processing Record 809 |  Labette
# 809 |  Labette has missing data.
# Processing Record 810 |  Cherokee
# Processing Record 811 |  Butler
# Processing Record 812 |  Greenwood
# Processing Record 813 |  Osage
# Processing Record 814 |  Woodson
# 814 |  Woodson has missing data.
# Processing Record 815 |  Allen
# Processing Record 816 |  Douglas
# Processing Record 817 |  Anderson
# Processing Record 818 |  Linn
# Processing Record 819 |  Marion districts (Kansas province)
# 819 |  Marion districts (Kansas province) has missing data.
# Processing Record 820 |  Calloway
# 820 |  Calloway has missing data.
# Processing Record 821 |  Webster
# Processing Record 822 | Daviess
# Processing Record 823 |  Mason
# Processing Record 824 |  Lewis
# Processing Record 825 |  Union
# Processing Record 826 |  Henderson
# Processing Record 827 |  Pulaski districts (Kentucky province)
# 827 |  Pulaski districts (Kentucky province) has missing data.
# Processing Record 828 |  Lawrence
# Processing Record 829 |  Cass
# Processing Record 830 |  Platte
# Processing Record 831 |  Clay
# Processing Record 832 |  Jackson- Kansas city
# 832 |  Jackson- Kansas city has missing data.
# Processing Record 833 |  Greene
# Processing Record 834 |  Christian
# 834 |  Christian has missing data.
# Processing Record 835 |  Camden
# Processing Record 836 |  Lewis
# Processing Record 837 |  Barton
# 837 |  Barton has missing data.
# Processing Record 838 |  Cedar
# Processing Record 839 |  Polk
# 839 |  Polk has missing data.
# Processing Record 840 |  Hickory
# Processing Record 841 |  Dallas
# Processing Record 842 |  Jasper
# Processing Record 843 |  Johnson
# Processing Record 844 |  Newton
# Processing Record 845 |  Dade
# 845 |  Dade has missing data.
# Processing Record 846 |  Pettis
# 846 |  Pettis has missing data.
# Processing Record 847 |  Dunklin
# 847 |  Dunklin has missing data.
# Processing Record 848 |  Pemiscot
# 848 |  Pemiscot has missing data.
# Processing Record 849 |  Putnam
# Processing Record 850 |  Scott
# Processing Record 851 |  Knox
# Processing Record 852 |  Scotland
# Processing Record 853 |  Clark
# Processing Record 854 |  Macon
# Processing Record 855 |  Shelby
# Processing Record 856 |  Mercer
# Processing Record 857 |  Lafayette
# Processing Record 858 |  Saline
# Processing Record 859 |  Cape Girardeau
# Processing Record 860 |  Bollinger
# 860 |  Bollinger has missing data.
# Processing Record 861 |  Pulaski districts (Missouri province)
# 861 |  Pulaski districts (Missouri province) has missing data.
# Processing Record 862 |  Marshall
# Processing Record 863 |  Benton
# Processing Record 864 |  Tippah
# 864 |  Tippah has missing data.
# Processing Record 865 |  Alcorn
# 865 |  Alcorn has missing data.
# Processing Record 866 |  Newton
# Processing Record 867 |  Scott
# Processing Record 868 |  Chickasaw
# Processing Record 869 |  Monroe
# Processing Record 870 |  Lee
# Processing Record 871 |  Itawamba
# 871 |  Itawamba has missing data.
# Processing Record 872 |  Madison
# Processing Record 873 |  Sunflower districts (Mississippi province)
# 873 |  Sunflower districts (Mississippi province) has missing data.
# Processing Record 874 |  Washington
# Processing Record 875 |  Vance
# Processing Record 876 |  Chowan
# 876 |  Chowan has missing data.
# Processing Record 877 |  Bertie
# 877 |  Bertie has missing data.
# Processing Record 878 |  Hertford
# Processing Record 879 |  Northamton districts (North Carolina province)
# 879 |  Northamton districts (North Carolina province) has missing data.
# Processing Record 880 |  Saunders district (Nebraska province)
# 880 |  Saunders district (Nebraska province) has missing data.
# Processing Record 881 |  Okhlaoma
# 881 |  Okhlaoma has missing data.
# ...
# Processing Record 3742 |  West Lodi in Seneca
# 3742 |  West Lodi in Seneca has missing data.
# Processing Record 3743 |  Galion in Crawford
# 3743 |  Galion in Crawford has missing data.
# Processing Record 3744 |  Steuben
# Processing Record 3745 |  Norwalk
# Processing Record 3746 |  Fitchville
# 3746 |  Fitchville has missing data.
# Processing Record 3747 |  Wakeman in Huron
# 3747 |  Wakeman in Huron has missing data.
# Processing Record 3748 |  Nova and Hayesville in Ashland
# 3748 |  Nova and Hayesville in Ashland has missing data.
# Processing Record 3749 |  South Vienna in Wayne
# 3749 |  South Vienna in Wayne has missing data.
# Processing Record 3750 |  Calcutta in Columbiana
# 3750 |  Calcutta in Columbiana has missing data.
# Processing Record 3751 |  Clark)
# 3751 |  Clark) has missing data.
# Processing Record 3752 |  Pennsylvania (Erie in Erie)
# 3752 |  Pennsylvania (Erie in Erie) has missing data.
# Processing Record 3753 |  Illinois (Noble in Richland)
# 3753 |  Illinois (Noble in Richland) has missing data.
# Processing Record 3754 | Keys islands
# 3754 | Keys islands has missing data.
# Processing Record 3755 |  Monroe
# Processing Record 3756 |  South Florida
# 3756 |  South Florida has missing data.
# Processing Record 3757 |  Jacksonville (Duval)
# 3757 |  Jacksonville (Duval) has missing data.
# Processing Record 3758 |  Marco Island
# 3758 |  Marco Island has missing data.
# Processing Record 3759 |  Naples (Collier)
# 3759 |  Naples (Collier) has missing data.
# Processing Record 3760 |  Fort Lauderdale (Broward)
# 3760 |  Fort Lauderdale (Broward) has missing data.
# Processing Record 3761 |  Lakeland (Polk)
# 3761 |  Lakeland (Polk) has missing data.
# Processing Record 3762 |  Orlando (Orange)
# 3762 |  Orlando (Orange) has missing data.
# Processing Record 3763 |  Clay (Florida)
# 3763 |  Clay (Florida) has missing data.
# Processing Record 3764 |  Savannah
# Processing Record 3765 |  Tybee Island (Chatham)
# 3765 |  Tybee Island (Chatham) has missing data.
# Processing Record 3766 |  Brunswick
# Processing Record 3767 |  St. Simons Island (Glynn)
# 3767 |  St. Simons Island (Glynn) has missing data.
# Processing Record 3768 |  McIntosh
# Processing Record 3769 |  Camden (Georgia)
# 3769 |  Camden (Georgia) has missing data.
# Processing Record 3770 |  Charleston
# Processing Record 3771 |  Folly Beach
# Processing Record 3772 |  the Isle of Palms
# 3772 |  the Isle of Palms has missing data.
# Processing Record 3773 |  Sullivan’s Island (Charleston) Hilton Head
# 3773 |  Sullivan’s Island (Charleston) Hilton Head has missing data.
# Processing Record 3774 |  Beaufort
# Processing Record 3775 |  Edisto Beach (Colleton) (South Carolina)
# 3775 |  Edisto Beach (Colleton) (South Carolina) has missing data.
# Processing Record 3776 | South Carolina
# Processing Record 3777 |  Georgia
# Processing Record 3778 | Georgia (cook)
# 3778 | Georgia (cook) has missing data.
# Processing Record 3779 |  Mississippi
# Processing Record 3780 |  Alabama
# Processing Record 3781 |  Louisiana
# Processing Record 3782 |  Florida states
# 3782 |  Florida states has missing data.
# Processing Record 3783 | Ellison Creek (Water wheel) Tonto National Forest (Gila
# 3783 | Ellison Creek (Water wheel) Tonto National Forest (Gila has missing data.
# Processing Record 3784 |  Arizona)
# 3784 |  Arizona) has missing data.
# Processing Record 3785 | San Jose (North California)
# 3785 | San Jose (North California) has missing data.
# Processing Record 3786 | Jersey shore
# Processing Record 3787 |  Seaside Park
# Processing Record 3788 |  Point Pleasant Beach (Ocean)
# 3788 |  Point Pleasant Beach (Ocean) has missing data.
# Processing Record 3789 |  Long Branch (Monmouth) (New Jersey)
# 3789 |  Long Branch (Monmouth) (New Jersey) has missing data.
# Processing Record 3790 |  Fernandina beach (Nassau-Florida)
# 3790 |  Fernandina beach (Nassau-Florida) has missing data.
# Processing Record 3791 | Mexico Gulf
# 3791 | Mexico Gulf has missing data.
# Processing Record 3792 |  Louisiania
# 3792 |  Louisiania has missing data.
# Processing Record 3793 |  Mississippi (coastal areas
# 3793 |  Mississippi (coastal areas has missing data.
# Processing Record 3794 |  Biloxi)
# 3794 |  Biloxi) has missing data.
# Processing Record 3795 |  Alabama (Dauphin Island
# 3795 |  Alabama (Dauphin Island has missing data.
# Processing Record 3796 |  Autauga
# 3796 |  Autauga has missing data.
# Processing Record 3797 |  Chilton
# Processing Record 3798 |  Lowndes Counties)
# 3798 |  Lowndes Counties) has missing data.
# Processing Record 3799 |  Florida
# Processing Record 3800 |  South Carolina (Pickens
# 3800 |  South Carolina (Pickens has missing data.
# Processing Record 3801 |  Laurens
# Processing Record 3802 |  Spartanburg
# Processing Record 3803 |  Newberry
# Processing Record 3804 |  Greenville
# Processing Record 3805 |  Union)
# 3805 |  Union) has missing data.
# Processing Record 3806 |  North Carolina (Polk
# 3806 |  North Carolina (Polk has missing data.
# Processing Record 3807 |  Wilkes
# 3807 |  Wilkes has missing data.
# Processing Record 3808 |  Ashe )
# 3808 |  Ashe ) has missing data.
# Processing Record 3809 | Butte (Oroville)
# 3809 | Butte (Oroville) has missing data.
# Processing Record 3810 |  San Luis Obispo
# Processing Record 3811 |  Santa Barbara (California)
# 3811 |  Santa Barbara (California) has missing data.
# Processing Record 3812 | Napa
# Processing Record 3813 |  Sonoma
# Processing Record 3814 |  Mendocino
# 3814 |  Mendocino has missing data.
# Processing Record 3815 |  Lake
# Processing Record 3816 |  Solano
# Processing Record 3817 |  Butte
# Processing Record 3818 |  Yuba
# 3818 |  Yuba has missing data.
# Processing Record 3819 |  Nevada
# Processing Record 3820 |  Humboldt
# Processing Record 3821 |  Calavaras
# 3821 |  Calavaras has missing data.
# Processing Record 3822 |  Orange counties (California)
# 3822 |  Orange counties (California) has missing data.
# Processing Record 3823 | Upper Midwest
# 3823 | Upper Midwest has missing data.
# Processing Record 3824 |  Northern Rockies and parts of the West
# 3824 |  Northern Rockies and parts of the West has missing data.
# Processing Record 3825 | Ventura
# Processing Record 3826 |  Santa Barbara
# Processing Record 3827 |  Los Angeles
# Processing Record 3828 |  San Diego
# Processing Record 3829 |  Riverside counties (California)
# 3829 |  Riverside counties (California) has missing data.
# Processing Record 3830 | Massachusetts
# Processing Record 3831 |  New York
# Processing Record 3832 |  Virginia
# Processing Record 3833 |  Maryland
# Processing Record 3834 | Kauai Isl. (Hawai)
# 3834 | Kauai Isl. (Hawai) has missing data.
# Processing Record 3835 | Hawaï
# Processing Record 3836 | Shasta
# Processing Record 3837 |  Trinity
# Processing Record 3838 |  Mendocino
# 3838 |  Mendocino has missing data.
# Processing Record 3839 |  Lake
# Processing Record 3840 |  Colusa
# Processing Record 3841 |  and Glenn counties (California)
# 3841 |  and Glenn counties (California) has missing data.
# Processing Record 3842 | Bastrop
# Processing Record 3843 |  Burnet
# Processing Record 3844 |  Colorado
# Processing Record 3845 |  Fayette
# Processing Record 3846 |  Hood
# 3846 |  Hood has missing data.
# Processing Record 3847 |  Jim Wells
# 3847 |  Jim Wells has missing data.
# Processing Record 3848 |  Kerr
# 3848 |  Kerr has missing data.
# Processing Record 3849 |  Kimble
# 3849 |  Kimble has missing data.
# Processing Record 3850 |  La Salle
# Processing Record 3851 |  Live Oak
# Processing Record 3852 |  Llano
# Processing Record 3853 |  Mason
# Processing Record 3854 |  McMullen
# 3854 |  McMullen has missing data.
# Processing Record 3855 |  Nueces
# 3855 |  Nueces has missing data.
# Processing Record 3856 |  Real
# Processing Record 3857 |  San Patricio
# Processing Record 3858 |  Travis
# 3858 |  Travis has missing data.
# Processing Record 3859 |  and Williamson counties
# 3859 |  and Williamson counties has missing data.
# Processing Record 3860 | Plains
# Processing Record 3861 |  SouthEast
# 3861 |  SouthEast has missing data.
# Processing Record 3862 |  Midwest
# 3862 |  Midwest has missing data.
# Processing Record 3863 |  NorthEast
# 3863 |  NorthEast has missing data.
# Processing Record 3864 | New Mexico
# Processing Record 3865 |  Texas
# Processing Record 3866 |  Iowa
# Processing Record 3867 |  Minnesota
# Processing Record 3868 |  Kansas
# Processing Record 3869 |  Louisiana
# Processing Record 3870 |  Tennessee
# Processing Record 3871 | South and North Carolina
# 3871 | South and North Carolina has missing data.
# Processing Record 3872 |  Virginia
# Processing Record 3873 | Santa Barbara County (Montecito and Carpinteria)
# 3873 | Santa Barbara County (Montecito and Carpinteria) has missing data.
# Processing Record 3874 |  Los Angeles County (Burbank)
# 3874 |  Los Angeles County (Burbank) has missing data.
# Processing Record 3875 |  Ventura (California)
# 3875 |  Ventura (California) has missing data.
# Processing Record 3876 | Florida
# Processing Record 3877 |  Georgia
# Processing Record 3878 |  Alabama
# Processing Record 3879 |  North Carolina
# Processing Record 3880 |  Virginia
# Processing Record 3881 |  Maryland
# Processing Record 3882 | Pella
# Processing Record 3883 |  Marshalltown (Iowa)
# 3883 |  Marshalltown (Iowa) has missing data.
# Processing Record 3884 | Colorado
# Processing Record 3885 |  PLains and Midwest
# 3885 |  PLains and Midwest has missing data.
# Processing Record 3886 | Wisconsin
# Processing Record 3887 |  Iowa
# Processing Record 3888 |  Minnesota
# Processing Record 3889 |  Missouri
# Processing Record 3890 |  Illinois
# Processing Record 3891 |  Kentucky
# Processing Record 3892 |  Pennsylvania
# Processing Record 3893 |  Arkansas
# Processing Record 3894 |  Ohio
# Processing Record 3895 |  Indiana
# Processing Record 3896 | New York City
# Processing Record 3897 |  Washington DC
# 3897 |  Washington DC has missing data.
# Processing Record 3898 |  Baltimore
# Processing Record 3899 |  Maryland
# Processing Record 3900 | Southeast
# Processing Record 3901 | Butte county (North California)
# 3901 | Butte county (North California) has missing data.
# Processing Record 3902 | Nationwide
# 3902 | Nationwide has missing data.
# Processing Record 3903 | Thousand Oaks
# Processing Record 3904 |  Oak Park
# Processing Record 3905 |  Westlake Village
# Processing Record 3906 |  Agoura Hills
# Processing Record 3907 |  West Hills
# Processing Record 3908 |  Simi Valley
# Processing Record 3909 |  Chatsworth
# Processing Record 3910 |  Bell Canyon
# 3910 |  Bell Canyon has missing data.
# Processing Record 3911 |  Hidden Hills
# Processing Record 3912 |  Malibu and Calabasas (California)
# 3912 |  Malibu and Calabasas (California) has missing data.
# Processing Record 3913 | Amador
# Processing Record 3914 |  Glenn
# 3914 |  Glenn has missing data.
# Processing Record 3915 |  Lake
# Processing Record 3916 |  Mendocino
# 3916 |  Mendocino has missing data.
# Processing Record 3917 |  Sonoma
# Processing Record 3918 |  Humboldt counties (California)
# 3918 |  Humboldt counties (California) has missing data.
# Processing Record 3919 | Midwest and Northeast
# 3919 | Midwest and Northeast has missing data.
# Processing Record 3920 | Northern California
# 3920 | Northern California has missing data.
# Processing Record 3921 | Robertson
# Processing Record 3922 |  Angelina
# Processing Record 3923 |  Houston and Cherokee Counties (Texas); Louisiana
# 3923 |  Houston and Cherokee Counties (Texas); Louisiana has missing data.
# Processing Record 3924 |  Arkansas
# Processing Record 3925 |  Mississippi
# Processing Record 3926 | Jefferson city
# Processing Record 3927 |  Golden (Barry county)
# 3927 |  Golden (Barry county) has missing data.
# Processing Record 3928 |  Carl Junction (Jasper county)
# 3928 |  Carl Junction (Jasper county) has missing data.
# Processing Record 3929 |  Missouri state
# 3929 |  Missouri state has missing data.
# Processing Record 3930 | Missouri
# Processing Record 3931 |  Nebraska
# Processing Record 3932 |  Indiana
# Processing Record 3933 |  Kansas
# Processing Record 3934 |  Louisiana
# Processing Record 3935 |  Mississippi
# Processing Record 3936 |  Alabama
# Processing Record 3937 |  Florida
# Processing Record 3938 |  Georgia
# Processing Record 3939 | Nebraska
# Processing Record 3940 |  Iowa
# Processing Record 3941 |  Wisconsin
# Processing Record 3942 |  Missouri
# Processing Record 3943 |  Kansas
# Processing Record 3944 |  Illinois
# Processing Record 3945 |  Minnesota
# Processing Record 3946 |  South Dakota
# Processing Record 3947 | Upper midwest
# 3947 | Upper midwest has missing data.
# Processing Record 3948 | Pacific Northwest
# 3948 | Pacific Northwest has missing data.
# Processing Record 3949 |  Rockies
# 3949 |  Rockies has missing data.
# Processing Record 3950 |  Northern Plains
# 3950 |  Northern Plains has missing data.
# Processing Record 3951 |  Upper Midwest
# 3951 |  Upper Midwest has missing data.
# Processing Record 3952 |  and the Northeast
# 3952 |  and the Northeast has missing data.
# Processing Record 3953 | Texas
# Processing Record 3954 |  Lousiana states
# 3954 |  Lousiana states has missing data.
# Processing Record 3955 | Texas
# Processing Record 3956 | Missouri
# Processing Record 3957 |  Illinois
# Processing Record 3958 |  Iowa
# Processing Record 3959 |  Kansas
# Processing Record 3960 |  Nebraska
# Processing Record 3961 |  Washington DC
# 3961 |  Washington DC has missing data.
# Processing Record 3962 |  Virginia
# Processing Record 3963 |  Colorado
# Processing Record 3964 |  North
# 3964 |  North has missing data.
# Processing Record 3965 |  South Carolina
# Processing Record 3966 | Alabama
# Processing Record 3967 |  Georgia
# Processing Record 3968 |  South Carolina
# Processing Record 3969 |  Florida
# Processing Record 3970 |  Mississippi
# Processing Record 3971 |
# 3971 |  has missing data.
# Processing Record 3972 | Texas
# Processing Record 3973 |  Arkansas
# Processing Record 3974 |  Oklahoma
# Processing Record 3975 |  Missouri
# Processing Record 3976 |  Louisiana
# Processing Record 3977 | Tennessee.
# 3977 | Tennessee. has missing data.
# Processing Record 3978 | Ridgecrest (Califronia)
# 3978 | Ridgecrest (Califronia) has missing data.
# Processing Record 3979 | Louisiana
# Processing Record 3980 |  Mississippi
# Processing Record 3981 |  Arkansas
# Processing Record 3982 |  Oklahoma
# Processing Record 3983 |  Great Lakes region
# 3983 |  Great Lakes region has missing data.
# Processing Record 3984 | Florida
# Processing Record 3985 |  Georgia
# Processing Record 3986 |  South Carolina
# Processing Record 3987 |  North Carolina
# Processing Record 3988 |  Virginia
# Processing Record 3989 | Los Angeles and Riverside counties (California)
# 3989 | Los Angeles and Riverside counties (California) has missing data.
# Processing Record 3990 | Los Angeles
# Processing Record 3991 |  San Bernardino
# Processing Record 3992 |  Ventura
# Processing Record 3993 |  Sonoma Counties (California)
# 3993 |  Sonoma Counties (California) has missing data.
# Processing Record 3994 | Lincolnton region (Lincoln County
# 3994 | Lincolnton region (Lincoln County has missing data.
# Processing Record 3995 |  North Carolina)
# 3995 |  North Carolina) has missing data.
# Processing Record 3996 | Louisiana
# Processing Record 3997 |  Texas
# Processing Record 3998 |  Mississippi
# Processing Record 3999 |  South Carolina
# Processing Record 4000 |  Georgia
# Processing Record 4001 |  Tennessee
# Processing Record 4002 |  Arkansas
# Processing Record 4003 |  North Carolina
# Processing Record 4004 |  Alabama
# Processing Record 4005 | Texas
# Processing Record 4006 |  Oklahoma
# Processing Record 4007 |  Missouri
# Processing Record 4008 |  Arkansas
# Processing Record 4009 |  Louisiana
# Processing Record 4010 |  Mississippi
# Processing Record 4011 |  Alabama
# Processing Record 4012 |  Tennessee
# Processing Record 4013 |  Kentucky
# Processing Record 4014 |  Georgia states
# 4014 |  Georgia states has missing data.
# Processing Record 4015 | Nashville (Tennessee)
# 4015 | Nashville (Tennessee) has missing data.
# Processing Record 4016 |  Kentucky
# Processing Record 4017 |  Missouri
# Processing Record 4018 |  Mississippi
# Processing Record 4019 |  Georgia
# Processing Record 4020 |  Texas
# Processing Record 4021 | errebonne
# 4021 | errebonne has missing data.
# Processing Record 4022 |  Plaquemines
# 4022 |  Plaquemines has missing data.
# Processing Record 4023 |  Lafourche Parishes (Louisiana)
# 4023 |  Lafourche Parishes (Louisiana) has missing data.

# %%
params1 = {
    "appid": openWeatherKey,
    "units": "imperial",
    "q": "Kentucky"
}
weatherUrl1 = "http://api.openweathermap.org/data/2.5/weather?"
response1 = requests.get(weatherUrl1, params=params1).json()
pprint(response1)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -30.77, 'lon': 151.45},
#  'dt': 1604551316,
#  'id': 2161599,
#  'main': {'feels_like': 59.41,
#           'humidity': 60,
#           'pressure': 1010,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Kentucky',
#  'sys': {'country': 'AU',
#          'id': 9604,
#          'sunrise': 1604516112,
#          'sunset': 1604564421,
#          'type': 1},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'gust': 29.97, 'speed': 17.22}}

# %%
coordLocations_df = splitLocations_df.loc[splitLocations_df["Lat"] != "N/A", ["Location", "Dis No", "Lat", "Long"]]
#This array is stored for potential future reference if adding new data from different dataframes
cleanedCoordsIndex = coordLocations_df.index
coordLocations_df.to_csv("output_data/coordLocations.csv")
coordLocations_df
# Out:
#           Location         Dis No    Lat    Long
# 0         Kentucky  2000-0080-USA -30.77  151.45
# 2           Morris  2000-0500-USA  40.83  -74.53
# 4          Alabama  2000-0919-USA  32.75  -86.75
# 5          Georgia  2000-0919-USA  32.75   -83.5
# 6        Louisiana  2000-0919-USA     31     -92
# ...            ...            ...    ...     ...
# 4016      Kentucky  2020-0082-USA -30.77  151.45
# 4017      Missouri  2020-0082-USA  38.25   -92.5
# 4018   Mississippi  2020-0082-USA  32.75  -89.75
# 4019       Georgia  2020-0082-USA  32.75   -83.5
# 4020         Texas  2020-0082-USA  31.25  -99.25
#
# [2861 rows x 4 columns]

# %%
thirdQuintant = coordLocations_df.loc[coordLocations_df[]]
